# %% [markdown]
# #### PRACTICAL 1:Python Basics

# %% [markdown]
# Data Types and Variables

# %%
x=10 
pi=3.14
name="ML Lab"
status=True 
print(x,pi,name,status)
# Out:
# 10 3.14 ML Lab True

# %% [markdown]
# Data Structures

# %%
lst=[1,2,3]
tup=(4,5,6)
sett={7,8,9}
dictn={"a":1,"b":2}
print(lst,tup,sett,dictn)
# Out:
# [1, 2, 3] (4, 5, 6) {8, 9, 7} {'a': 1, 'b': 2}

# %%
list=[1,2,3,4]
print(list)
# Out:
# [1, 2, 3, 4]

# %%
tuple=(1,2,3,4)
print(tuple)
# Out:
# (1, 2, 3, 4)

# %%
set={7,8,9}
print(set)
# Out:
# {8, 9, 7}

# %%
tuple=([1,2,3])
print(tuple)
# Out:
# [1, 2, 3]

# %%
tuple=[(1,2,3,4)]
print(tuple)
# Out:
# [(1, 2, 3, 4)]

# %% [markdown]
# #### PRACTICAL 2:Control Structures & Functions

# %% [markdown]
# If-else

# %%
num=15
if num>10:
    print("Greater than 10")
else:
    print("less than or equal to 10")
# Out:
# Greater than 10

# %%
num=125
if num<65:
    print("how are you")
else:
    print("i am fine")
# Out:
# i am fine

# %% [markdown]
# Loop

# %%
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# Function

# %%
def square(n):
    return n * n
print(square(5))
# Out:
# 25

# %% [markdown]
# #### PRACTICAL 3:NumPy Operations

# %%
import numpy as np
arr=np.array([1,2,3,4,5])
print(arr)
print(arr.mean())
print(arr*2)
# Out:
# [1 2 3 4 5]
# 3.0
# [ 2  4  6  8 10]

# %% [markdown]
# #### PRACTICAL 4:Pandas Data Handling

# %%
import pandas as pd
data={"Name":["A","B","C"],"Marks":[78,85,90]}
df=pd.DataFrame(data)
print(df)
# Out:
#   Name  Marks
# 0    A     78
# 1    B     85
# 2    C     90

# %%
import pandas as pd
mishul=["kanika","ansh","bhawri","rohini"]
score=[78,85,90,55]
df=pd.DataFrame(mishul)
print(df)
# Out:
#         0
# 0  kanika
# 1    ansh
# 2  bhawri
# 3  rohini

# %%
df.head(1)
# Out:
#         0
# 0  kanika

# %%
df.head(-1)
# Out:
#         0
# 0  kanika
# 1    ansh
# 2  bhawri

# %%
df.tail(1)
# Out:
#         0
# 3  rohini

# %%
df.tail(-1)
# Out:
#         0
# 1    ansh
# 2  bhawri
# 3  rohini

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       4 non-null      object
# dtypes: object(1)
# memory usage: 164.0+ bytes

# %%
df.describe()
# Out:
#              0
# count        4
# unique       4
# top     kanika
# freq         1

# %% [markdown]
# Data Exploration

# %%
print(df.head())
print(df.info())
print(df.describe())
# Out:
#   Name  Marks
# 0    A     78
# 1    B     85
# 2    C     90
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Marks   3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes
# None
#            Marks
# count   3.000000
# mean   84.333333
# std     6.027714
# min    78.000000
# 25%    81.500000
# 50%    85.000000
# 75%    87.500000
# max    90.000000

# %% [markdown]
# #### PRACTICAL 5:Import CSV File

# %%
#df=pd.read_csv("data.csv")
#print(df.head())

# %%
import pandas as pd
mishul=["kanika","ansh","bhawri","rohini"]
score=[78,85,90,55]
df=pd.DataFrame({"name":mishul,"score":score})
#save to csv file
df.to_csv("mishul.csv",index=False)
print("csv file created successfully")
print(df)
# Out:
# csv file created successfully
#      name  score
# 0  kanika     78
# 1    ansh     85
# 2  bhawri     90
# 3  rohini     55

# %%
df= pd.read_csv("mishul.csv")
print(df)
# Out:
#      name  score
# 0  kanika     78
# 1    ansh     85
# 2  bhawri     90
# 3  rohini     55

# %%
print(df["score"])
# Out:
# 0    78
# 1    85
# 2    90
# 3    55
# Name: score, dtype: int64

# %% [markdown]
# #### PRACTICAL 6:Data Slicing & indexing

# %%
print(df["score"])
print(df.loc[0])
print(df.iloc[1])
# Out:
# 0    78
# 1    85
# 2    90
# 3    55
# Name: score, dtype: int64
# name     kanika
# score        78
# Name: 0, dtype: object
# name     ansh
# score      85
# Name: 1, dtype: object

# %%
print(df.loc[0])
# Out:
# name     kanika
# score        78
# Name: 0, dtype: object

# %%
print(df.loc[1])
# Out:
# name     ansh
# score      85
# Name: 1, dtype: object

# %%
print(df.loc[0:2,["name","score"]])
# Out:
#      name  score
# 0  kanika     78
# 1    ansh     85
# 2  bhawri     90

# %% [markdown]
# #### PRACTICAL 7:Data Visualization(matplotlib)

# %%
import pandas as pd
import matplotlib.pyplot as plt
data={"name":["kanika","ansh","bhawri","rohini"],"score":[78,85,90,55]}
df=pd.DataFrame(data)
plt.plot(df["name"],df["score"])
plt.xlabel("Students")
plt.ylabel("score")
plt.title("Student Marks")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data={"name":["kanika","ansh","bhawri","rohini"],"score":[78,85,90,55]}
df=pd.DataFrame(data)
plt.hist(df["score"],bins=5)
plt.xlabel("score")
plt.ylabel("number of students")
plt.title("histogram of student marks")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data={"name":["kanika","ansh","bhawri","rohini"],"score":[78,85,90,55]}
df=pd.DataFrame(data)
plt.pie(df["score"],labels=df["name"],autopct='%1.1f%%',startangle=90)
plt.title("pie chart")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data={"name":["kanika","ansh","bhawri","rohini"],"score":[78,85,90,55]}
df=pd.DataFrame(data)
plt.bar(df['name'],df['score'])
plt.xlabel('students')
plt.ylabel('marks')
plt.title("bar chart of student marks")
plt.show()

# %% [markdown]
# #### PRACTICAL 8:Data Visualization(Seaborn)

# %% [markdown]
# Seaborn is basically for large dataset

# %%
import seaborn as sns
sns.barplot(x="Name",y="Marks",data=df)
plt.title("Marks Bar Chart")
plt.show()

# %% [markdown]
# #### PRACTICAL 9:Simple Regression Model

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
X=np.array([[1],[2],[3],[4],[5]])
Y=np.array([2,4,6,8,10])
model=LinearRegression()
model.fit(X,Y)
pred=model.predict([[6]])
print("Prediction:",pred)
# Out:
# Prediction: [12.]

# %% [markdown]
# #### PRACTICAL 10:Classification Model

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
iris=load_iris()
X,Y=iris.data, iris.target
X_train, X_test, Y_train, Y_test=train_test_split(X,Y,test_size=0.3)
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,Y_train)
Y_pred=knn.predict(X_test)
print("Accuracy:",accuracy_score(Y_test,Y_pred))
# Out:
# Accuracy: 0.9111111111111111

# %% [markdown]
# #### CONFUSION MATRIX

# %%
from sklearn.metrics import confusion_matrix

# Calculate the confusion matrix
cm = confusion_matrix(Y_test, Y_pred)

# ---- GRAPH ----
plt.imshow(cm)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("Actual Label")
plt.colorbar()

# Add values inside cells
for i in range(len(cm)):
    for j in range(len(cm)):
        plt.text(j, i, cm[i, j], ha="center", va="center")

plt.show()
